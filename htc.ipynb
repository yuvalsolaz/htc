# %%
import pandas as pd
import matplotlib.pyplot as plt

from presentation import draw_labels, draw_decision_boundary
from dataset import load_data, create_dataset, split_dataset, GEO_FIELDS
from classifier import classify, classifiers

# %% [markdown]
# ### load table data

# %%
table_name = r'data/ut-sample-rand.csv'
table = load_data(table_name)
# Out:
# loading data/ut-sample-rand.csv...
# (522284, 12) records loaded

# %%
table.head()
# Out:
#                    LON                 LAT NUMBER           STREET UNIT  \
# 0         -112.2770003          40.6578373   7078  N LAKE POINT RD  NaN
# 1         -112.2805534  40.657812899999996   7079       N RIDGE RD  NaN
# 2  -112.27825890000001          40.6580349   7087  N LAKE POINT RD  NaN
# 3         -112.2792997          40.6580281   7088       N RIDGE RD  NaN
# 4         -112.2770033           40.658251   7102  N LAKE POINT RD  NaN
#
#          CITY DISTRICT REGION POSTCODE             ID              HASH  \
# 0  LAKE POINT      NaN     UT    84074  16-061-0-0213  97b1d37691f8dc50
# 1  LAKE POINT      NaN     UT    84074  16-061-0-0203  de31e805386b5c04
# 2  LAKE POINT      NaN     UT    84074  16-061-0-0217  01ccd9e8c5f7fa1f
# 3  LAKE POINT      NaN     UT    84074  16-061-0-0221  b2ae7b10754a511e
# 4  LAKE POINT      NaN     UT    84074  16-061-0-0214  18048d91a0f7ead4
#
#   SHULY_RAND
# 0        XXX
# 1        XXX
# 2        XYZ
# 3        ZZZ
# 4    UNKNOWN

# %%
table.describe()
# Out:
#                  LON         LAT  NUMBER     STREET    UNIT            CITY  \
# count         522284      522284  522168     522280  259945          454448
# unique        443511      460499   17067      14603   20336             100
# top     -111.8243965  41.7623761    4000  S MAIN ST     RES  SALT LAKE CITY
# freq             133         133    1253       4404  103888           93307
#
#        DISTRICT  REGION POSTCODE              ID              HASH SHULY_RAND
# count         0  522284   522284          510708            522284     522284
# unique        0       1       97          374419            521882          5
# top         NaN      UT    84015  15343770120000  eb4af9a08c632fdf        ZZZ
# freq        NaN  522284    23130            1226                16     104728

# %%
field_names = list(set(table.columns[1:]) - set(GEO_FIELDS) - set(['HASH','ID']))
print(f'geographic fields names: {GEO_FIELDS}')
print(f'attributes fields names: {field_names}')
# Out:
# geographic fields names: ['LAT', 'LON']
# attributes fields names: ['POSTCODE', 'NUMBER', 'STREET', 'UNIT', 'CITY', 'DISTRICT', 'REGION', 'SHULY_RAND']

# %%
results = []

# %%
fig, axs = plt.subplots(nrows=len(field_names), ncols=2, sharex='none', figsize=(17,60))
for i, field_name in enumerate(field_names):
    print(f'creating data set from {field_name} field on {table_name} table...')
    X,y = create_dataset(table=table, field_name=field_name)
    if X is None or y is None:
        continue
    classes_count = len(set(y))
    print(f'{field_name} have {classes_count} distinct values')
    if classes_count < 2:
        continue
    X_train, X_test, y_train, y_test = split_dataset(X, y)
    clf = classifiers[0]
    clf_name = str(clf)
    print(f'start classify {field_name} label with {clf_name}...')
    score = classify(X_train=X_train, X_test=X_test, y_train=y_train, y_test=y_test, clf=clf)
    print ( f'{clf_name} finished with {score} score')
    results.append({'field_name':field_name,
                    'classes_count':classes_count,
                    'classifier_name':clf_name,
                    'score':score})
    draw_labels(X=X_test , y=y_test , ax=axs[i,0], title='test')
    draw_decision_boundary(X=X, clf=clf, ax=axs[i,1],
                          title = f'decision line {field_name} label {classes_count} classes {score} score')
# Out:
# creating data set from POSTCODE field on data/ut-sample-rand.csv table...
# (522284, 12) after drop nan
# set geo fields as X features
# standartize feature values
# set POSTCODE field as label
# POSTCODE have 97 distinct values
# split train test 80.0% - 20.0%
# start classify POSTCODE label with KNeighborsClassifier()...
# KNeighborsClassifier() finished with 0.9955675541131758 score
# decision class : 84307 with 3492 occurances
# creating data set from NUMBER field on data/ut-sample-rand.csv table...
# (522168, 12) after drop nan
# set geo fields as X features
# standartize feature values
# /home/yuvalso/repository/htc/presentation.py:41: UserWarning: The following kwargs were not used by contour: 'c'
#   ax.contourf(xx, yy, Z, c=colors, cmap= cm_colors, alpha=.8)
# set NUMBER field as label
# NUMBER have 17067 distinct values
# split train test 80.0% - 20.0%
# start classify NUMBER label with KNeighborsClassifier()...
# KNeighborsClassifier() finished with 0.20694409866518568 score
# decision class : 2600 with 1995 occurances
# creating data set from STREET field on data/ut-sample-rand.csv table...
# (522280, 12) after drop nan
# set geo fields as X features
# standartize feature values
# /home/yuvalso/repository/htc/presentation.py:41: UserWarning: The following kwargs were not used by contour: 'c'
#   ax.contourf(xx, yy, Z, c=colors, cmap= cm_colors, alpha=.8)
# set STREET field as label
# STREET have 14603 distinct values
# split train test 80.0% - 20.0%
# start classify STREET label with KNeighborsClassifier()...
# KNeighborsClassifier() finished with 0.7433943478593857 score
# decision class : HIGLEY RD with 2085 occurances
# creating data set from UNIT field on data/ut-sample-rand.csv table...
# (259945, 12) after drop nan
# set geo fields as X features
# standartize feature values
# set UNIT field as label
# UNIT have 20336 distinct values
# split train test 80.0% - 20.0%
# /home/yuvalso/repository/htc/presentation.py:41: UserWarning: The following kwargs were not used by contour: 'c'
#   ax.contourf(xx, yy, Z, c=colors, cmap= cm_colors, alpha=.8)
# start classify UNIT label with KNeighborsClassifier()...
# KNeighborsClassifier() finished with 0.4808901883090654 score
# decision class : RES with 2537 occurances
# creating data set from CITY field on data/ut-sample-rand.csv table...
# (454448, 12) after drop nan
# set geo fields as X features
# standartize feature values
# /home/yuvalso/repository/htc/presentation.py:41: UserWarning: The following kwargs were not used by contour: 'c'
#   ax.contourf(xx, yy, Z, c=colors, cmap= cm_colors, alpha=.8)
# set CITY field as label
# CITY have 100 distinct values
# split train test 80.0% - 20.0%
# start classify CITY label with KNeighborsClassifier()...
# KNeighborsClassifier() finished with 0.9971504015843327 score
# decision class : GRANTSVILLE with 2815 occurances
# creating data set from DISTRICT field on data/ut-sample-rand.csv table...
# only 0 values after drop nan
#   useless field: DISTRICT
# creating data set from REGION field on data/ut-sample-rand.csv table...
# (522284, 12) after drop nan
# set geo fields as X features
# standartize feature values
# /home/yuvalso/repository/htc/presentation.py:41: UserWarning: The following kwargs were not used by contour: 'c'
#   ax.contourf(xx, yy, Z, c=colors, cmap= cm_colors, alpha=.8)
# set REGION field as label
# REGION have 1 distinct values
# creating data set from SHULY_RAND field on data/ut-sample-rand.csv table...
# (522284, 12) after drop nan
# set geo fields as X features
# standartize feature values
# set SHULY_RAND field as label
# SHULY_RAND have 5 distinct values
# split train test 80.0% - 20.0%
# start classify SHULY_RAND label with KNeighborsClassifier()...
# KNeighborsClassifier() finished with 0.20079075600486324 score
# decision class : UNKNOWN with 9396 occurances
# /home/yuvalso/repository/htc/presentation.py:41: UserWarning: The following kwargs were not used by contour: 'c'
#   ax.contourf(xx, yy, Z, c=colors, cmap= cm_colors, alpha=.8)

# %%
pd.DataFrame(results)
# Out:
#    field_name  classes_count         classifier_name     score
# 0    POSTCODE             97  KNeighborsClassifier()  0.995568
# 1      NUMBER          17067  KNeighborsClassifier()  0.206944
# 2      STREET          14603  KNeighborsClassifier()  0.743394
# 3        UNIT          20336  KNeighborsClassifier()  0.480890
# 4        CITY            100  KNeighborsClassifier()  0.997150
# 5  SHULY_RAND              5  KNeighborsClassifier()  0.200791
